# %% [markdown]
# <a href="https://colab.research.google.com/github/npr99/PlanningMethods/blob/master/PLAN604_0av1_US_Census_Geography.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Understanding US Census Geography
#
# This program focuses on obtaining US Census Geography shapefiles.

# %%
# Install packages not included in Google Colab (-q = option quiet)
# !pip -q install geopandas
# Import packages
import sys # For checking version of python for replication
import os   # For saving output to path
import pandas as pd # For reading, writing and wrangling data
import geopandas as gpd # For creating maps
import folium as fm # For creating the final HTML map complete with OSM (Open Street Map) basemap

from google.colab import files  # Required to automatedownload final files

# %% [markdown]
# Using the wget command download the cartographic boundaries files from the US Census website.
#
# The cartographic files come in three levels of resolution. The "smallest" file size will be the lowest resolution - 20m = 1:20,000,000. For smaller geographies the 5m = 1:5,000,000 resolution and the 500k = 1:500,000 resolutions provide more details.

# %%
# Program Prepare Geography combines steps needed to prepare files for mapping
def prepare_geography(year,state,entity,resolution):
  filename = f'cb_{year}_{state}_{entity}_{resolution}'

  # !wget -q https://www2.census.gov/geo/tiger/GENZ2019/shp/{filename}.zip

  # !unzip -o -q {filename}.zip
  gdf = gpd.read_file(f'{filename}.shp')
  gdf = gdf.to_crs(epsg=4326)
  
  return gdf

# %% [markdown]
# ## Create a list of the geographies to be prepared
# The list includes the geographic entity and the resolution.

# %%
state = '48'
entities = [['us','nation','5m'],
            ['us','region','5m'],
            ['us','division','5m'],
            ['us','state','5m'],
            ['us','county','5m'],
            ['us','cbsa','20m'],
            ['us','aiannh','500k'],
            ['us','ua10','500k'],
            [state,'place','500k'],
            [state,'tract','500k'],
            [state,'bg','500k']]

# %%
geographies = {}
for entity in entities:
    geographies[entity[1]] = prepare_geography('2019',entity[0],entity[1],entity[2])

    # Approximate measure of sq km area based on Equal Area Cylindrical projection (cea)
    # https://proj.org/operations/projections/cea.html
    geographies[entity[1]]= geographies[entity[1]].to_crs({'proj':'cea'})
    geographies[entity[1]]["areasqkm"] = geographies[entity[1]]['geometry'].area/ 10**6

    # Set geography to EPSG 4326
    # EPSG: 4326 uses a coordinate system  (Lat, Lon) on the surface of a sphere
    # with the WGS84 datum. Open Street Map and Google Earth use 4326.
    geographies[entity[1]]= geographies[entity[1]].to_crs(epsg = 4326)

    count = len(geographies[entity[1]])
    print('US Census Geographic Entity:',entity[1], '\t count = ',count,'\t\t state = ',entity[0])
# Out:
# US Census Geographic Entity: nation 	 count =  1 		 state =  us
# US Census Geographic Entity: region 	 count =  4 		 state =  us
# US Census Geographic Entity: division 	 count =  9 		 state =  us
# US Census Geographic Entity: state 	 count =  56 		 state =  us
# US Census Geographic Entity: county 	 count =  3233 		 state =  us
# US Census Geographic Entity: cbsa 	 count =  938 		 state =  us
# US Census Geographic Entity: aiannh 	 count =  695 		 state =  us
# US Census Geographic Entity: ua10 	 count =  3601 		 state =  us
# US Census Geographic Entity: place 	 count =  1746 		 state =  48
# US Census Geographic Entity: tract 	 count =  5254 		 state =  48
# US Census Geographic Entity: bg 	 count =  15800 		 state =  48

# %%
def create_column(entity):
  column = geographies[entity][["areasqkm"]].describe()
  column = column.rename(columns = {"areasqkm" : entity})
  column.loc["Total"] = geographies[entity]["areasqkm"].sum()

  column.loc["% Total"] = geographies[entity]["areasqkm"].sum() / geographies['nation']["areasqkm"].sum() * 100

  return column

columns = {}
for entity in entities:
  columns[entity[1]] = create_column(entity[1])

# %%
table1 = pd.concat([columns['nation'], 
                    columns['region'],
                    columns['division'],
                    columns['state'],
                    columns['county'],
                    columns['cbsa'],
                    columns['aiannh']], axis=1)
varformat = "{:,.0f}"
table_title = "Table 1. Descriptive statistics for approximate area (sq km) for US Census Geographies."
table1 = table1.style.set_caption(table_title).format(varformat).set_properties(**{'text-align': 'right'})
table1
# Out:
# <style  type="text/css" >
#     #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row0_col0 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row0_col1 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row0_col2 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row0_col3 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row0_col4 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row0_col5 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row0_col6 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row1_col0 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row1_col1 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row1_col2 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row1_col3 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row1_col4 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row1_col5 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row1_col6 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row2_col0 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row2_col1 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row2_col2 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row2_col3 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row2_col4 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row2_col5 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row2_col6 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row3_col0 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row3_col1 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row3_col2 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row3_col3 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row3_col4 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row3_col5 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row3_col6 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row4_col0 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row4_col1 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row4_col2 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row4_col3 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row4_col4 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row4_col5 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row4_col6 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row5_col0 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row5_col1 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row5_col2 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row5_col3 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row5_col4 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row5_col5 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row5_col6 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row6_col0 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row6_col1 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row6_col2 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row6_col3 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row6_col4 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row6_col5 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row6_col6 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row7_col0 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row7_col1 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row7_col2 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row7_col3 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row7_col4 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row7_col5 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row7_col6 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row8_col0 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row8_col1 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row8_col2 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row8_col3 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row8_col4 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row8_col5 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row8_col6 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row9_col0 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row9_col1 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row9_col2 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row9_col3 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row9_col4 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row9_col5 {
#             text-align:  right;
#         }    #T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row9_col6 {
#             text-align:  right;
#         }</style><table id="T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002" ><caption>Table 1. Descriptive statistics for approximate area (sq km) for US Census Geographies.</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >nation</th>        <th class="col_heading level0 col1" >region</th>        <th class="col_heading level0 col2" >division</th>        <th class="col_heading level0 col3" >state</th>        <th class="col_heading level0 col4" >county</th>        <th class="col_heading level0 col5" >cbsa</th>        <th class="col_heading level0 col6" >aiannh</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row0_col1" class="data row0 col1" >4</td>
#                         <td id="T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row0_col2" class="data row0 col2" >9</td>
#                         <td id="T_ca54b6b0_ee03_11ea_8e84_0242ac1c0002row0_col3" class="data row0 col3" >56</td>

# %%
table2 = pd.concat([columns['tract'],
                    columns['bg'],
                    columns['place']], axis=1)
varformat = "{:,.0f}"
table_title = "Table 2. Descriptive statistics for approximate area (sq km) for Texas Census Geographies."
table2 = table2.style.set_caption(table_title).format(varformat).set_properties(**{'text-align': 'right'})
table2
# Out:
# <style  type="text/css" >
#     #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row0_col0 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row0_col1 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row0_col2 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row1_col0 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row1_col1 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row1_col2 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row2_col0 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row2_col1 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row2_col2 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row3_col0 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row3_col1 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row3_col2 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row4_col0 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row4_col1 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row4_col2 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row5_col0 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row5_col1 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row5_col2 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row6_col0 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row6_col1 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row6_col2 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row7_col0 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row7_col1 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row7_col2 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row8_col0 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row8_col1 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row8_col2 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row9_col0 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row9_col1 {
#             text-align:  right;
#         }    #T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row9_col2 {
#             text-align:  right;
#         }</style><table id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002" ><caption>Table 2. Descriptive statistics for approximate area (sq km) for Texas Census Geographies.</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >tract</th>        <th class="col_heading level0 col1" >bg</th>        <th class="col_heading level0 col2" >place</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row0_col0" class="data row0 col0" >5,254</td>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row0_col1" class="data row0 col1" >15,800</td>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row0_col2" class="data row0 col2" >1,746</td>
#             </tr>
#             <tr>
#                         <th id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row1_col0" class="data row1 col0" >131</td>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row1_col1" class="data row1 col1" >44</td>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row1_col2" class="data row1 col2" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row2_col0" class="data row2 col0" >547</td>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row2_col1" class="data row2 col1" >266</td>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row2_col2" class="data row2 col2" >75</td>
#             </tr>
#             <tr>
#                         <th id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002level0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row3_col0" class="data row3 col0" >0</td>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row3_col1" class="data row3 col1" >0</td>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row3_col2" class="data row3 col2" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002level0_row4" class="row_heading level0 row4" >25%</th>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row4_col0" class="data row4 col0" >2</td>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row4_col1" class="data row4 col1" >1</td>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row4_col2" class="data row4 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002level0_row5" class="row_heading level0 row5" >50%</th>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row5_col1" class="data row5 col1" >1</td>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row5_col2" class="data row5 col2" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002level0_row6" class="row_heading level0 row6" >75%</th>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row6_col0" class="data row6 col0" >28</td>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row6_col1" class="data row6 col1" >6</td>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row6_col2" class="data row6 col2" >14</td>
#             </tr>
#             <tr>
#                         <th id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002level0_row7" class="row_heading level0 row7" >max</th>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row7_col0" class="data row7 col0" >16,016</td>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row7_col1" class="data row7 col1" >9,525</td>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row7_col2" class="data row7 col2" >1,740</td>
#             </tr>
#             <tr>
#                         <th id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002level0_row8" class="row_heading level0 row8" >Total</th>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row8_col0" class="data row8 col0" >687,749</td>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row8_col1" class="data row8 col1" >687,749</td>
#                         <td id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002row8_col2" class="data row8 col2" >35,734</td>
#             </tr>
#             <tr>
#                         <th id="T_ca5a4daa_ee03_11ea_8e84_0242ac1c0002level0_row9" class="row_heading level0 row9" >% Total</th>

# %%
# Create a guide for the map styles for each entity
# Colors from Color Brewer
# https://colorbrewer2.org/#type=sequential&scheme=BuGn&n=5

maplayers = [['nation','region'],
             ['region','division'],
             ['region','state'],
             ['state','county'],
             ['nation','cbsa'],
             ['nation','aiannh'],
             ['state','place'],
             ['county','tract']]

# Make directory to save output
if not os.path.exists('output_maplayers'):
    os.mkdir('output_maplayers')

# %%
style_function1 = lambda x: {
            'fillColor': 'transparent',
            'color': 'red',
            'weight': 4,
            'fillOpacity': 0
        }
style_function2 = lambda x: {
            'fillColor': 'green',
            'color': 'black',
            'weight': 1,
            'fillOpacity': 0.25
        }

highlight_function1 = lambda x: {'fillOpacity': 0.5}

maps = {}
for layer in maplayers:
    entity1 = layer[0]
    entity2 = layer[1]
    mapname = entity1+entity2
    print(mapname)

    # What location should the map be centered on?
    center_x = (geographies[entity2].bounds.minx.mean() + geographies[entity2].bounds.maxx.mean())/2
    center_y = (geographies[entity2].bounds.miny.mean() + geographies[entity2].bounds.maxy.mean())/2
    print(f'The center of the {entity2} data file is located at {center_x} {center_y}')

    maps[mapname] = fm.Map(location=[center_y, center_x], 
        max_bounds = True,
        control_scale=True,
        prefer_canvas=True)

    fm.GeoJson(
            geographies[entity1].to_json(),
            name= entity1,
            style_function= style_function1,
            highlight_function=False,
            tooltip=fm.features.GeoJsonTooltip(fields=['NAME','AFFGEOID','GEOID'], sticky=True)                
        ).add_to(maps[mapname])

    fm.GeoJson( 
            geographies[entity2].to_json(),
            name= entity2,
            style_function=style_function2,
            highlight_function=highlight_function1,
            tooltip=fm.features.GeoJsonTooltip(fields=['NAME','AFFGEOID','GEOID'], sticky=False) 
        ).add_to(maps[mapname] )

    fm.LayerControl(collapsed=False, autoZIndex=False).add_to(maps[mapname])

    # How should the map be bound - look for the southwest and northeast corners of the data
    sw_corner = [geographies[entity2].bounds.miny.min(),geographies[entity2].bounds.minx.min()]
    ne_corner = [geographies[entity2].bounds.maxy.max(),geographies[entity2].bounds.maxx.max()]
    print(f'The {entity2} data file is bounded by at {sw_corner} {ne_corner}')
    maps[mapname].fit_bounds([sw_corner, ne_corner])

    maps[mapname].save(f'output_maplayers/{mapname}.html')
    #files.download(f'output_maplayers/{mapname}.html')
# Out:
# nationregion
# The center of the region data file is located at -64.13868232500144 40.89900360565585
# The region data file is bounded by at [18.917461314593385, -179.14733999999999] [71.35256099911636, 179.77847011250077]
# regiondivision
# The center of the division data file is located at -78.4711968359081 39.49159054260613
# The division data file is bounded by at [18.917461314593385, -179.14733999999999] [71.35256099911636, 179.77847011250077]
# regionstate
# The center of the state data file is located at -82.68060043007272 36.952816396775916
# The state data file is bounded by at [-14.552548987193942, -179.14733999999999] [71.35256099911636, 179.77847011250077]
# statecounty
# The center of the county data file is located at -91.33944886914709 37.830518833949625
# The county data file is bounded by at [-14.552548987193942, -179.14733999999999] [71.35256099911636, 179.77847011250077]
# nationcbsa
# The center of the cbsa data file is located at -92.35587211232635 37.884555963079656
# The cbsa data file is bounded by at [17.913768986086932, -160.2496158344034] [65.45352299884728, -65.564931]
# nationaiannh
# The center of the aiannh data file is located at -126.63672050979801 44.334259811469096
# The aiannh data file is bounded by at [18.910597652860094, -174.23452138400464] [71.33971025251311, -67.0385279826039]
# stateplace
# The center of the place data file is located at -97.81747998757614 30.62202311181933
# The place data file is bounded by at [25.84031798658832, -106.635926] [36.499733991408505, -93.56609799999998]
# countytract
# The center of the tract data file is located at -97.4714547089282 31.010524233089118
# The tract data file is bounded by at [25.83737698658744, -106.645646] [36.50070399140901, -93.508292]

# %%
display(maps['nationaiannh'])
